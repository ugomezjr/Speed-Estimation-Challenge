# %% [markdown]
# <a href="https://colab.research.google.com/github/ugomezjr/Speed-Estimation-Challenge/blob/main/speed_estimation_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ugomezjr/Speed-Estimation-Challenge.git
# !mv Speed-Estimation-Challenge/download_data.py Speed-Estimation-Challenge/extract_frames.py Speed-Estimation-Challenge/train.py .
# !mv Speed-Estimation-Challenge/utils/ . 
# !rm -rf Speed-Estimation-Challenge/ sample_data/

# %%
# download data from github.com/commaai/speedchallenge
# !python3 download_data.py --train_dir=./data/train --test_dir=./data/test
# Out:
# ...
# 100% 130034541/130034541 [00:00<00:00, 251995244.50it/s]
# ...
# 100% 194353/194353 [00:00<00:00, 8273710.14it/s]
# ...
# 100% 66954539/66954539 [00:00<00:00, 207966594.40it/s]

# %%
# !python3 extract_frames.py --data_path=./data/train --fname=train.mp4

# %%
import matplotlib.pyplot as plt
from PIL import Image

plt.imshow(Image.open('./data/train/frame0.png'))
plt.axis(False);

# %%
# !python3 train.py
